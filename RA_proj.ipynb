# %% [markdown]
# # Imports

# %%
library(regclass)
library(dplyr)

# %% [markdown]
# # Read Data

# %%
data_raw <- read.csv("House_Rent_Dataset.csv", header=TRUE)

# %%
data_raw
# Out:
#      Posted.On  BHK Rent   Size Floor                   Area.Type
# 1    2022-05-18 2   10000  1100 Ground out of 2         Super Area
# 2    2022-05-13 2   20000   800 1 out of 3              Super Area
# 3    2022-05-16 2   17000  1000 1 out of 3              Super Area
# 4    2022-07-04 2   10000   800 1 out of 2              Super Area
# 5    2022-05-09 2    7500   850 1 out of 2              Carpet Area
# 6    2022-04-29 2    7000   600 Ground out of 1         Super Area
# 7    2022-06-21 2   10000   700 Ground out of 4         Super Area
# 8    2022-06-21 1    5000   250 1 out of 2              Super Area
# 9    2022-06-07 2   26000   800 1 out of 2              Carpet Area
# 10   2022-06-20 2   10000  1000 1 out of 3              Carpet Area
# 11   2022-05-23 3   25000  1200 1 out of 4              Carpet Area
# 12   2022-06-07 1    5000   400 1 out of 1              Carpet Area
# 13   2022-05-14 1    6500   250 1 out of 4              Carpet Area
# ...

# %%
colnames(data_raw)
# Out:
#  [1] "Posted.On"         "BHK"               "Rent"
#  [4] "Size"              "Floor"             "Area.Type"
#  [7] "Area.Locality"     "City"              "Furnishing.Status"
# [10] "Tenant.Preferred"  "Bathroom"          "Point.of.Contact"

# %%
drops <- c("Posted.On", "Floor", "Area.Locality")

data <- data_raw[ , !(names(data_raw) %in% drops)]
data
# Out:
#      BHK Rent   Size Area.Type   City      Furnishing.Status Tenant.Preferred
# 1    2   10000  1100 Super Area  Kolkata   Unfurnished       Bachelors/Family
# 2    2   20000   800 Super Area  Kolkata   Semi-Furnished    Bachelors/Family
# 3    2   17000  1000 Super Area  Kolkata   Semi-Furnished    Bachelors/Family
# 4    2   10000   800 Super Area  Kolkata   Unfurnished       Bachelors/Family
# 5    2    7500   850 Carpet Area Kolkata   Unfurnished       Bachelors
# 6    2    7000   600 Super Area  Kolkata   Unfurnished       Bachelors/Family
# 7    2   10000   700 Super Area  Kolkata   Unfurnished       Bachelors
# 8    1    5000   250 Super Area  Kolkata   Unfurnished       Bachelors
# 9    2   26000   800 Carpet Area Kolkata   Unfurnished       Bachelors
# 10   2   10000  1000 Carpet Area Kolkata   Semi-Furnished    Bachelors/Family
# 11   3   25000  1200 Carpet Area Kolkata   Semi-Furnished    Bachelors/Family
# ...

# %%
colnames(data)
# Out:
# [1] "BHK"               "Rent"              "Size"
# [4] "Area.Type"         "City"              "Furnishing.Status"
# [7] "Tenant.Preferred"  "Bathroom"          "Point.of.Contact"

# %%
discrete_cols <- c('BHK', 'Bathroom')

categorical_cols <- c('Area.Type', 'City', 'Furnishing.Status', 'Tenant.Preferred', 'Point.of.Contact')

numerical_cols <- c('Size')

y_cols <- c('Rent')

# %%
for (col in c(discrete_cols, categorical_cols)){
    unique_list   <- unique(data[[col]])
    unique_count  <- length(unique_list)
    print(c(col, unique_count))
}
# Out:
# [1] "BHK" "6"
# [1] "Bathroom" "8"
# [1] "Area.Type" "3"
# [1] "City" "6"
# [1] "Furnishing.Status" "3"
# [1] "Tenant.Preferred" "3"
# [1] "Point.of.Contact" "3"

# %%
for (col in c(discrete_cols, categorical_cols)){
    unique_list   <- unique(data[[col]])
    unique_count  <- length(unique_list)
    print(c(col, unique_list))
}
# Out:
# [1] "BHK" "2"   "1"   "3"   "6"   "4"   "5"
# [1] "Bathroom" "2"        "1"        "3"        "5"        "4"        "6"
# [8] "7"        "10"
# [1] "Area.Type"   "Super Area"  "Carpet Area" "Built Area"
# [1] "City"      "Kolkata"   "Mumbai"    "Bangalore" "Delhi"     "Chennai"
# [7] "Hyderabad"
# [1] "Furnishing.Status" "Unfurnished"       "Semi-Furnished"
# [4] "Furnished"
# [1] "Tenant.Preferred" "Bachelors/Family" "Bachelors"        "Family"
# [1] "Point.of.Contact" "Contact Owner"    "Contact Agent"    "Contact Builder"

# %% [markdown]
# # Data Encoding

# %%
data$Area.Type.Built = recode(data$Area.Type, "Carpet Area"=0, "Built Area"=1, "Super Area"=0)
data$Area.Type.Super = recode(data$Area.Type, "Carpet Area"=0, "Built Area"=0, "Super Area"=1)

# %%
table(data$Area.Type)
# Out:
#  Built Area Carpet Area  Super Area
#           2        2298        2446

# %%
table(data$Area.Type.Built)
table(data$Area.Type.Super)
# Out:
#    0    1
# 4744    2
#    0    1
# 2300 2446

# %%
table(data$City)
# Out:
# Bangalore   Chennai     Delhi Hyderabad   Kolkata    Mumbai
#       886       891       605       868       524       972

# %%
data$City.Bangalore = recode(data$City, "Delhi"=0, "Bangalore"=1, "Chennai"=0, "Hyderabad"=0, "Kolkata"=0, "Mumbai"=0)
data$City.Chennai   = recode(data$City, "Delhi"=0, "Bangalore"=0, "Chennai"=1, "Hyderabad"=0, "Kolkata"=0, "Mumbai"=0)
data$City.Hyderabad = recode(data$City, "Delhi"=0, "Bangalore"=0, "Chennai"=0, "Hyderabad"=1, "Kolkata"=0, "Mumbai"=0)
data$City.Kolkata   = recode(data$City, "Delhi"=0, "Bangalore"=0, "Chennai"=0, "Hyderabad"=0, "Kolkata"=1, "Mumbai"=0)
data$City.Mumbai    = recode(data$City, "Delhi"=0, "Bangalore"=0, "Chennai"=0, "Hyderabad"=0, "Kolkata"=0, "Mumbai"=1)

# %%
table(data$City.Bangalore)
table(data$City.Chennai)
table(data$City.Hyderabad)
table(data$City.Kolkata)
table(data$City.Mumbai)
# Out:
#    0    1
# 3860  886
#    0    1
# 3855  891
#    0    1
# 3878  868
#    0    1
# 4222  524
#    0    1
# 3774  972

# %%
table(data$Furnishing.Status)
# Out:
#      Furnished Semi-Furnished    Unfurnished
#            680           2251           1815

# %%
data$Furnishing.Status.Furnished     = recode(data$Furnishing.Status, "Unfurnished"=0, "Furnished"=1, "Semi-Furnished"=0)
data$Furnishing.Status.SemiFurnished = recode(data$Furnishing.Status, "Unfurnished"=0, "Furnished"=0, "Semi-Furnished"=1)

# %%
table(data$Furnishing.Status.Furnished)
table(data$Furnishing.Status.SemiFurnished)
# Out:
#    0    1
# 4066  680
#    0    1
# 2495 2251

# %%
table(data$Tenant.Preferred)
# Out:
#        Bachelors Bachelors/Family           Family
#              830             3444              472

# %%
data$Tenant.Preferred.Bachelors  = recode(data$Tenant.Preferred, "Bachelors/Family"=0, "Bachelors"=1, "Family"=0)
data$Tenant.Preferred.Family     = recode(data$Tenant.Preferred, "Bachelors/Family"=0, "Bachelors"=0, "Family"=1)

# %%
table(data$Tenant.Preferred.Bachelors)
table(data$Tenant.Preferred.Family)
# Out:
#    0    1
# 3916  830
#    0    1
# 4274  472

# %%
table(data$Point.of.Contact)
# Out:
#   Contact Agent Contact Builder   Contact Owner
#            1529               1            3216

# %%
data$Point.of.Contact.ContactAgent   = recode(data$Point.of.Contact, "Contact Owner"=0, "Contact Agent"=1, "Contact Builder"=0)
data$Point.of.Contact.ContactBuilder = recode(data$Point.of.Contact, "Contact Owner"=0, "Contact Agent"=0, "Contact Builder"=1)

# %%
table(data$Point.of.Contact.ContactAgent)
table(data$Point.of.Contact.ContactBuilder)
# Out:
#    0    1
# 3217 1529
#    0    1
# 4745    1

# %%
colnames(data)
# Out:
#  [1] "BHK"                             "Rent"
#  [3] "Size"                            "Area.Type"
#  [5] "City"                            "Furnishing.Status"
#  [7] "Tenant.Preferred"                "Bathroom"
#  [9] "Point.of.Contact"                "Area.Type.Built"
# [11] "Area.Type.Super"                 "City.Bangalore"
# [13] "City.Chennai"                    "City.Hyderabad"
# [15] "City.Kolkata"                    "City.Mumbai"
# [17] "Furnishing.Status.Furnished"     "Furnishing.Status.SemiFurnished"
# [19] "Tenant.Preferred.Bachelors"      "Tenant.Preferred.Family"
# [21] "Point.of.Contact.ContactAgent"   "Point.of.Contact.ContactBuilder"

# %%
cols_to_keep <- c('Rent', 'Size', 'BHK', 'Bathroom', 'Area.Type.Built', 'Area.Type.Super', 'City.Bangalore', 
                 'City.Chennai', 'City.Hyderabad', 'City.Kolkata', 'City.Mumbai', 'Furnishing.Status.Furnished', 
                 'Furnishing.Status.SemiFurnished', 'Tenant.Preferred.Bachelors', 'Tenant.Preferred.Family', 
                 'Point.of.Contact.ContactAgent', 'Point.of.Contact.ContactBuilder')

# %%
data <- data[cols_to_keep]

# %% [markdown]
# # Train test Split

# %%
set.seed(7)

# %%
nrow(data)
# Out:
# [1] 4746

# %%
# Train Test Split

train_idxs <- sample(1:nrow(data), nrow(data)*0.70)  # by %

test_idxs  <- -1*train_idxs

train_set  <- data[train_idxs,]
test_set   <- data[test_idxs,]

# %%
train_set
# Out:
#      Rent   Size BHK Bathroom Area.Type.Built Area.Type.Super City.Bangalore
# 1491  45000  670 2   2        0               0               0
# 4572  16000 1100 2   2        0               1               0
# 2754  30000  900 2   2        0               1               0
# 2678  25000  900 2   2        0               0               0
# 3064  16000  850 2   2        0               1               0
# 1496 250000 2729 4   5        0               0               0
# 3976 100000 3300 4   4        0               0               0
# 571   65000  710 2   2        0               0               0
# 4364  10000 1030 2   2        0               1               0
# 947   40000  710 2   2        0               0               0
# 2964  16500  950 2   1        0               0               0
# 2034   8000  400 1   1        0               1               1
# 4303  70000 3200 3   3        0               0               0
# ...

# %%
attach(train_set)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Scatter plot

# %%
# data[, c(discrete_cols, numerical_cols, y_cols)]

# %%
pairs(train_set[, c(y_cols, numerical_cols, discrete_cols)])
# Out:
# plot without title

# %%
plot(train_set$Size, train_set$Rent, xlab="Size", ylab="Rent", main="Indian Houses", pch=19)
# Out:
# Plot with title "Indian Houses"

# %%
plot(train_set$BHK, train_set$Rent, xlab="BHK", ylab="Rent", main="Indian Houses", pch=19)
# Out:
# Plot with title "Indian Houses"

# %%
plot(train_set$Bathroom, train_set$Rent, xlab="Bathroom", ylab="Rent", main="Indian Houses", pch=19)
# Out:
# Plot with title "Indian Houses"

# %% [markdown]
# ## Corr

# %%
corr_matrix <- cor(train_set[, c(y_cols, numerical_cols, discrete_cols)])  
print(corr_matrix)
# Out:
#               Rent      Size       BHK  Bathroom
# Rent     1.0000000 0.5052569 0.4603134 0.5444761
# Size     0.5052569 1.0000000 0.7132826 0.7426097
# BHK      0.4603134 0.7132826 1.0000000 0.7863520
# Bathroom 0.5444761 0.7426097 0.7863520 1.0000000

# %%
all_corr = cor(train_set)
all_corr
# Out:
#                                 Rent         Size         BHK
# Rent                             1.000000000  0.505256916  0.46031340
# Size                             0.505256916  1.000000000  0.71328257
# BHK                              0.460313395  0.713282572  1.00000000
# Bathroom                         0.544476137  0.742609654  0.78635196
# Area.Type.Built                 -0.008145543 -0.012750477 -0.02267397
# Area.Type.Super                 -0.269543358 -0.079368103 -0.15358632
# City.Bangalore                  -0.110057172 -0.004067209 -0.10791504
# City.Chennai                    -0.106636734  0.047402614  0.02085924
# City.Hyderabad                  -0.103380951  0.175392413  0.07760917
# City.Kolkata                    -0.127754290 -0.092979256 -0.02790272
# City.Mumbai                      0.436589840 -0.040755778  0.02649912
# Furnishing.Status.Furnished      0.152620547  0.060280155  0.04992644
# Furnishing.Status.SemiFurnished  0.030399113  0.153061764  0.12692560
# ...

# %%
write.csv(all_corr, "all_corr.csv")

# %% [markdown]
# ## Describe

# %%
# install.packages('Hmisc')
# library(Hmisc)
# Out:
# Warning message:
# "package 'Hmisc' was built under R version 4.1.3"
# Loading required package: lattice
#
# Warning message:
# "package 'lattice' was built under R version 4.1.3"
#
# Attaching package: 'lattice'
#
#
# The following object is masked from 'package:regclass':
#
#     qq
#
#
# Loading required package: survival
#
# Warning message:
# "package 'survival' was built under R version 4.1.3"
# Loading required package: Formula
#
# Loading required package: ggplot2
#
# Warning message:
# "package 'ggplot2' was built under R version 4.1.3"
#
# Attaching package: 'ggplot2'
#
#
# The following object is masked from 'package:randomForest':
#
#     margin
#
#
#
# Attaching package: 'Hmisc'
#
#
# The following objects are masked from 'package:dplyr':
#
#     src, summarize
#
#
# The following objects are masked from 'package:base':
#
#     format.pval, units

# %%
describe(train_set)
# Out:
# train_set
#
#  17  Variables      3322  Observations
# --------------------------------------------------------------------------------
# Rent
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#     3322        0      205    0.999    34088    38853     6000     7000
#      .25      .50      .75      .90      .95
#    10000    16000    32000    70000   130000
#
# lowest :    1500    1800    2000    2200    3000
# highest:  600000  650000  850000 1000000 1200000
# --------------------------------------------------------------------------------
# Size
#        n  missing distinct     Info     Mean      Gmd      .05      .10
#     3322        0      511    0.999    970.7    633.6    220.3    400.0
#      .25      .50      .75      .90      .95
#    560.0    850.0   1200.0   1700.0   2000.0
#
# lowest :   25   30   40   42   45, highest: 5000 5700 6000 7000 8000
# --------------------------------------------------------------------------------
# BHK
# ...

# %%
write.csv(train_set, "train_set.csv")

# %% [markdown]
# # Hypothesis Testing

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    Area.Type.Built + Area.Type.Super +
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent + Point.of.Contact.ContactBuilder)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + Area.Type.Built +
#     Area.Type.Super + City.Bangalore + City.Chennai + City.Hyderabad +
#     City.Kolkata + City.Mumbai + Furnishing.Status.Furnished +
#     Furnishing.Status.SemiFurnished + Tenant.Preferred.Bachelors +
#     Tenant.Preferred.Family + Point.of.Contact.ContactAgent +
#     Point.of.Contact.ContactBuilder)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139451  -17991   -2116   11937  940798
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -26576.299   3406.200  -7.802 8.09e-15 ***
# Size                                36.602      1.921  19.058  < 2e-16 ***
# BHK                               4682.447   1549.197   3.022 0.002526 **
# Bathroom                          8414.917   1601.880   5.253 1.59e-07 ***
# Area.Type.Built                  24998.881  42400.786   0.590 0.555509
# ...

# %% [markdown]
# ## Size

# %%
                            
n <- nrow(train_set)  # n observations

beta_hat  <- 36.602
beta_null <- 0
std_error <- 1.921

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))


signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"         "19.0536179073399"
# [1] "p_value:" "0"
# [1] "reject_Ho"

# %% [markdown]
# ## BHK

# %%
beta_hat  <- 4682.447
beta_null <- 0
std_error <- 1549.197

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"         "3.02249939807526"
# [1] "p_value:"            "0.00252619954970168"
# [1] "reject_Ho"

# %% [markdown]
# ## Bathroom

# %%
beta_hat  <- 8414.917   
beta_null <- 0
std_error <- 1601.880

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"         "5.25315067295927"
# [1] "p_value:"             "1.58984710285637e-07"
# [1] "reject_Ho"

# %% [markdown]
# ## Area.Type.Built

# %%
                
beta_hat  <- 24998.881
beta_null <- 0
std_error <- 42400.786

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"         "0.58958532042307"
# [1] "p_value:"          "0.555508996556346"
# [1] "fail_to_reject_Ho"

# %% [markdown]
# ## Area.Type.Super

# %%
                   
beta_hat  <- -2693.581
beta_null <- 0
std_error <- 1892.738

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-1.42311350012522"
# [1] "p_value:"          "0.154797640036216"
# [1] "fail_to_reject_Ho"

# %% [markdown]
# ## City.Bangalore

# %%
beta_hat  <- -10951.174
beta_null <- 0
std_error <- 2774.296

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-3.94737043199428"
# [1] "p_value:"             "8.06596570459888e-05"
# [1] "reject_Ho"

# %% [markdown]
# ## City.Chennai

# %%
beta_hat  <- -15313.267
beta_null <- 0
std_error <- 2758.894

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-5.55050937078409"
# [1] "p_value:"             "3.07309184152401e-08"
# [1] "reject_Ho"

# %% [markdown]
# ## City.Hyderabad

# %%
beta_hat  <- -23821.055
beta_null <- 0
std_error <- 2848.897

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-8.36150095984516"
# [1] "p_value:"           "9.010198891196e-17"
# [1] "reject_Ho"

# %% [markdown]
# ## City.Kolkata

# %%
beta_hat  <- -11898.191
beta_null <- 0
std_error <- 3134.062 

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-3.79641213224244"
# [1] "p_value:"             "0.000149441200904036"
# [1] "reject_Ho"

# %% [markdown]
# ## City.Mumbai

# %%
beta_hat  <- 43746.185
beta_null <- 0
std_error <- 2850.350

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"         "15.3476537969021"
# [1] "p_value:" "2"
# [1] "fail_to_reject_Ho"

# %% [markdown]
# ## Furnishing.Status.Furnished

# %%
beta_hat  <- 7886.053
beta_null <- 0
std_error <- 2331.039

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"        "3.3830635180278"
# [1] "p_value:"             "0.000725162873095986"
# [1] "reject_Ho"

# %% [markdown]
# ## Furnishing.Status.SemiFurnished

# %%
beta_hat  <- -1356.429
beta_null <- 0
std_error <- 1678.804

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"           "-0.807973414406923"
# [1] "p_value:"          "0.419164036209274"
# [1] "fail_to_reject_Ho"

# %% [markdown]
# ## Tenant.Preferred.Bachelors

# %%
beta_hat  <- -3712.767
beta_null <- 0
std_error <- 2160.331

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-1.71861025000336"
# [1] "p_value:"           "0.0857790141219126"
# [1] "fail_to_reject_Ho"

# %% [markdown]
# ## Tenant.Preferred.Family

# %%
beta_hat  <- -7219.560
beta_null <- 0
std_error <- 2538.531

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "-2.84399126896619"
# [1] "p_value:"            "0.00448260623850002"
# [1] "reject_Ho"

# %% [markdown]
# ## Point.of.Contact.ContactAgent

# %%
beta_hat  <- 7988.083
beta_null <- 0
std_error <- 2232.332

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"        "3.5783579682592"
# [1] "p_value:"             "0.000350724895275878"
# [1] "reject_Ho"

# %% [markdown]
# ## Point.of.Contact.ContactBuilder

# %%
beta_hat  <- 30852.684
beta_null <- 0
std_error <- 42370.495

t_value   <-  (beta_hat - beta_null) / std_error
print(c('t_value:', t_value))
p_value   <-  2*(1-pt(t_value, df=n-17))
print(c('p_value:', p_value))

signif_level  <- 0.05

if (p_value > signif_level){
    ans <- "fail_to_reject_Ho"
} else {
    ans <- "reject_Ho"
}
print(ans)
# Out:
# [1] "t_value:"          "0.728164351159929"
# [1] "p_value:"          "0.466564571150319"
# [1] "fail_to_reject_Ho"

# %% [markdown]
# # Confidence Interval

# %% [markdown]
# ## Size

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 36.602
std_error <- 1.921

conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] 32.83553 40.36847

# %% [markdown]
# ## BHK

# %%
confint(model)
# Out:
#                                 2.5 %       97.5 %
# (Intercept)                     -33254.7742 -19897.82341
# Size                                32.8365     40.36794
# BHK                               1644.9644   7719.92899
# Bathroom                          5274.1401  11555.69360
# Area.Type.Built                 -58135.5792 108133.34046
# Area.Type.Super                  -6404.6380   1017.47562
# City.Bangalore                  -16390.6869  -5511.66099
# City.Chennai                    -20722.5804  -9903.95301
# City.Hyderabad                  -29406.8356 -18235.27471
# City.Kolkata                    -18043.0901  -5753.29136
# City.Mumbai                      38157.5548  49334.81558
# Furnishing.Status.Furnished       3315.6258  12456.48007
# Furnishing.Status.SemiFurnished  -4648.0290   1935.17122
# Tenant.Preferred.Bachelors       -7948.4894    522.95444
# Tenant.Preferred.Family         -12196.8128  -2242.30680
# Point.of.Contact.ContactAgent     3611.1896  12364.97660
# ...

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 4682.447
std_error <- 1549.197

conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] 1644.964 7719.930

# %% [markdown]
# ## Bathroom

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 8414.917
std_error <- 1601.880

conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1]  5274.14 11555.69

# %% [markdown]
# ## Area.Type.Built

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 24998.881
std_error <- 42400.786

conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -58135.58 108133.34

# %% [markdown]
# ## Area.Type.Super

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -2693.581
std_error <- 1892.738

conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -6404.638  1017.476

# %% [markdown]
# ## City.Bangalore

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -10951.174
std_error <- 2774.296

conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -16390.686  -5511.662

# %% [markdown]
# ## City.Chennai

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -15313.267
std_error <- 2758.894


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -20722.581  -9903.953

# %% [markdown]
# ## City.Hyderabad

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -23821.055
std_error <- 2848.897


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -29406.84 -18235.27

# %% [markdown]
# ## City.Kolkata

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -11898.191
std_error <-  3134.062 


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -18043.090  -5753.292

# %% [markdown]
# ## City.Mumbai

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 43746.185
std_error <- 2850.350


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] 38157.55 49334.82

# %% [markdown]
# ## Furnishing.Status.Furnished

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 7886.053
std_error <- 2331.039


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1]  3315.627 12456.479

# %% [markdown]
# ## Furnishing.Status.SemiFurnished

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -1356.429
std_error <- 1678.804


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -4648.030  1935.172

# %% [markdown]
# ## Tenant.Preferred.Bachelors

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -3712.767
std_error <- 2160.331


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -7948.4892   522.9552

# %% [markdown]
# ## Tenant.Preferred.Family

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- -7219.560
std_error <- 2538.531


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -12196.812  -2242.308

# %% [markdown]
# ## Point.of.Contact.ContactAgent

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 7988.083
std_error <- 2232.332


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1]  3611.19 12364.98

# %% [markdown]
# ## Point.of.Contact.ContactBuilder

# %%
n <- nrow(train_set)         # sample_size

beta_hat  <- 30852.684
std_error <- 42370.495


conf_level  <- 0.95                                 # = 95 %
percentile  <- conf_level + (1 - conf_level)/2      # = 97.5 %
t_value     <- qt(percentile, df=n-17)               # = 2.01

cutoff_lhs <- beta_hat - t_value*std_error
cutoff_rhs <- beta_hat + t_value*std_error

confidence_interval <- c(cutoff_lhs, cutoff_rhs)
print(confidence_interval)
# Out:
# [1] -52222.38 113927.75

# %% [markdown]
# # Modelling

# %%
# library(regclass)

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    Area.Type.Built + Area.Type.Super +
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent + Point.of.Contact.ContactBuilder)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + Area.Type.Built +
#     Area.Type.Super + City.Bangalore + City.Chennai + City.Hyderabad +
#     City.Kolkata + City.Mumbai + Furnishing.Status.Furnished +
#     Furnishing.Status.SemiFurnished + Tenant.Preferred.Bachelors +
#     Tenant.Preferred.Family + Point.of.Contact.ContactAgent +
#     Point.of.Contact.ContactBuilder)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139451  -17991   -2116   11937  940798
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -26576.299   3406.200  -7.802 8.09e-15 ***
# Size                                36.602      1.921  19.058  < 2e-16 ***
# BHK                               4682.447   1549.197   3.022 0.002526 **
# Bathroom                          8414.917   1601.880   5.253 1.59e-07 ***
# Area.Type.Built                  24998.881  42400.786   0.590 0.555509
# ...

# %%
# model <- lm(Rent ~ Size + BHK + Bathroom + Area.Type + City  + Furnishing.Status + Tenant.Preferred + Point.of.Contact)

# summary(model)

# %%
# model <- lm(Rent ~ Size + BHK + Bathroom + Area.Type + City  + Furnishing.Status + Tenant.Preferred + Point.of.Contact + 
#             data_raw$Floor + data_raw$Area.Locality
#            )

# summary(model)

# %% [markdown]
# # Multicollinearity Check

# %% [markdown]
# ## VIF

# %%
vif_table <- VIF(model)
# print(vif_table)

# %%
data.frame(vif_table)
# Out:
#                            Size                             BHK
#                        2.808507                        3.129912
#                        Bathroom                 Area.Type.Built
#                        3.798661                        1.003912
#                 Area.Type.Super                  City.Bangalore
#                        1.659332                        2.159916
#                    City.Chennai                  City.Hyderabad
#                        2.173161                        2.240364
#                    City.Kolkata                     City.Mumbai
#                        1.748183                        2.462268
#     Furnishing.Status.Furnished Furnishing.Status.SemiFurnished
#                        1.235547                        1.304085
#      Tenant.Preferred.Bachelors         Tenant.Preferred.Family
#                        1.206831                        1.104298
#   Point.of.Contact.ContactAgent Point.of.Contact.ContactBuilder
# ...

# %%
# write.csv(vif_table, "vif_table.csv")

# %%
# cor(
#          data.frame(Rent, Size , BHK , Bathroom , 
#                     Area.Type.Built , Area.Type.Super ,
#                     City.Bangalore , City.Chennai , City.Hyderabad , City.Kolkata , City.Mumbai ,
#                     Furnishing.Status.Furnished , Furnishing.Status.SemiFurnished , 
#                     Tenant.Preferred.Bachelors , Tenant.Preferred.Family , 
#                     Point.of.Contact.ContactAgent , Point.of.Contact.ContactBuilder)
# )

# %%
cor(train_set)
# Out:
#                                 Rent         Size         BHK
# Rent                             1.000000000  0.505256916  0.46031340
# Size                             0.505256916  1.000000000  0.71328257
# BHK                              0.460313395  0.713282572  1.00000000
# Bathroom                         0.544476137  0.742609654  0.78635196
# Area.Type.Built                 -0.008145543 -0.012750477 -0.02267397
# Area.Type.Super                 -0.269543358 -0.079368103 -0.15358632
# City.Bangalore                  -0.110057172 -0.004067209 -0.10791504
# City.Chennai                    -0.106636734  0.047402614  0.02085924
# City.Hyderabad                  -0.103380951  0.175392413  0.07760917
# City.Kolkata                    -0.127754290 -0.092979256 -0.02790272
# City.Mumbai                      0.436589840 -0.040755778  0.02649912
# Furnishing.Status.Furnished      0.152620547  0.060280155  0.04992644
# Furnishing.Status.SemiFurnished  0.030399113  0.153061764  0.12692560
# ...

# %% [markdown]
# ## Using Adjusted R^2

# %%
# In next section

# %% [markdown]
# # Effect on Regression Coefficients

# %% [markdown]
# ## X1

# %%
model_1 <- lm(Rent ~ Size)

summary(model_1)
# Out:
# Call:
# lm(formula = Rent ~ Size)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -171457  -22191   -8284    8948  975740
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -11725.222   1627.044  -7.206 7.08e-13 ***
# Size            47.197      1.399  33.735  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 51650 on 3320 degrees of freedom
# Multiple R-squared:  0.2553,	Adjusted R-squared:  0.2551
# F-statistic:  1138 on 1 and 3320 DF,  p-value: < 2.2e-16

# %%
model_2 <- lm(Rent ~ BHK)

summary(model_2)
# Out:
# Call:
# lm(formula = Rent ~ BHK)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -142370  -21807  -12952   11048 1103339
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -34756       2482  -14.00   <2e-16 ***
# BHK            32854       1100   29.88   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 53140 on 3320 degrees of freedom
# Multiple R-squared:  0.2119,	Adjusted R-squared:  0.2117
# F-statistic: 892.6 on 1 and 3320 DF,  p-value: < 2.2e-16

# %%
model_3 <- lm(Rent ~ Bathroom)

summary(model_3)
# Out:
# Call:
# lm(formula = Rent ~ Bathroom)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -182504  -22131   -5131   10869 1091920
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -37818.8     2110.6  -17.92   <2e-16 ***
# Bathroom     36474.7      975.2   37.40   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 50200 on 3320 degrees of freedom
# Multiple R-squared:  0.2965,	Adjusted R-squared:  0.2962
# F-statistic:  1399 on 1 and 3320 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## X1, X2

# %%
model <- lm(Rent ~ Size + BHK)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -169422  -22007   -8399   11425 1002699
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -28991.688   2403.563  -12.06   <2e-16 ***
# Size            33.644      1.969   17.09   <2e-16 ***
# BHK          14518.407   1504.458    9.65   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 50950 on 3319 degrees of freedom
# Multiple R-squared:  0.2756,	Adjusted R-squared:  0.2752
# F-statistic: 631.4 on 2 and 3319 DF,  p-value: < 2.2e-16

# %%
model <- lm(Rent ~ Size + Bathroom)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + Bathroom)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -184805  -21527   -4226   10879 1029937
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -36153.587   2082.609  -17.36   <2e-16 ***
# Size            21.019      1.998   10.52   <2e-16 ***
# Bathroom     25280.999   1432.633   17.65   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 49390 on 3319 degrees of freedom
# Multiple R-squared:  0.3192,	Adjusted R-squared:  0.3188
# F-statistic: 777.9 on 2 and 3319 DF,  p-value: < 2.2e-16

# %%
model <- lm(Rent ~ BHK + Bathroom)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ BHK + Bathroom)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -183666  -22430   -5445   11606 1089470
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -41671       2365 -17.617  < 2e-16 ***
# BHK             6015       1679   3.583 0.000345 ***
# Bathroom       32035       1576  20.330  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 50110 on 3319 degrees of freedom
# Multiple R-squared:  0.2992,	Adjusted R-squared:  0.2987
# F-statistic: 708.4 on 2 and 3319 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## x1, x2, x3

# %%
model <- lm(Rent ~ Size + BHK + Bathroom)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -179688  -21488   -4345   10845 1030385
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -36579.143   2387.938 -15.318   <2e-16 ***
# Size            20.779      2.103   9.879   <2e-16 ***
# BHK            634.864   1742.239   0.364    0.716
# Bathroom     24940.024   1711.304  14.574   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 49400 on 3318 degrees of freedom
# Multiple R-squared:  0.3192,	Adjusted R-squared:  0.3186
# F-statistic: 518.5 on 3 and 3318 DF,  p-value: < 2.2e-16

# %% [markdown]
# # Model Selection

# %% [markdown]
# ## Forward-up Approach

# %% [markdown]
# ### 1

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    Area.Type.Built + Area.Type.Super +
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent + Point.of.Contact.ContactBuilder)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + Area.Type.Built +
#     Area.Type.Super + City.Bangalore + City.Chennai + City.Hyderabad +
#     City.Kolkata + City.Mumbai + Furnishing.Status.Furnished +
#     Furnishing.Status.SemiFurnished + Tenant.Preferred.Bachelors +
#     Tenant.Preferred.Family + Point.of.Contact.ContactAgent +
#     Point.of.Contact.ContactBuilder)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139451  -17991   -2116   11937  940798
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -26576.299   3406.200  -7.802 8.09e-15 ***
# Size                                36.602      1.921  19.058  < 2e-16 ***
# BHK                               4682.447   1549.197   3.022 0.002526 **
# Bathroom                          8414.917   1601.880   5.253 1.59e-07 ***
# Area.Type.Built                  24998.881  42400.786   0.590 0.555509
# ...

# %%
vif_table <- VIF(model)
data.frame(vif_table)
# Out:
#                                 vif_table
# Size                            2.808507
# BHK                             3.129912
# Bathroom                        3.798661
# Area.Type.Built                 1.003912
# Area.Type.Super                 1.659332
# City.Bangalore                  2.159916
# City.Chennai                    2.173161
# City.Hyderabad                  2.240364
# City.Kolkata                    1.748183
# City.Mumbai                     2.462268
# Furnishing.Status.Furnished     1.235547
# Furnishing.Status.SemiFurnished 1.304085
# Tenant.Preferred.Bachelors      1.206831
# Tenant.Preferred.Family         1.104298
# Point.of.Contact.ContactAgent   2.012083
# Point.of.Contact.ContactBuilder 1.002478

# %%
vif_table <- VIF(model)
data.frame(vif_table)$vif_table
# Out:
#  [1] 2.808507 3.129912 3.798661 1.003912 1.659332 2.159916 2.173161 2.240364
#  [9] 1.748183 2.462268 1.235547 1.304085 1.206831 1.104298 2.012083 1.002478

# %% [markdown]
# ### Remove `Area.Type.Built`

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    Area.Type.Super +
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent + Point.of.Contact.ContactBuilder)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + Area.Type.Super +
#     City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata +
#     City.Mumbai + Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished +
#     Tenant.Preferred.Bachelors + Tenant.Preferred.Family + Point.of.Contact.ContactAgent +
#     Point.of.Contact.ContactBuilder)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139437  -18002   -2136   11933  940804
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -26503.11    3403.60  -7.787 9.13e-15 ***
# Size                                36.61       1.92  19.062  < 2e-16 ***
# BHK                               4670.68    1548.91   3.015 0.002585 **
# Bathroom                          8410.31    1601.70   5.251 1.61e-07 ***
# Area.Type.Super                  -2736.41    1891.16  -1.447 0.148006
# City.Bangalore                  -10951.29    2774.02  -3.948 8.05e-05 ***
# ...

# %%
vif_table <- VIF(model)
data.frame(vif_table)$vif_table
# Out:
#  [1] 2.808452 3.129392 3.798571 1.656889 2.159916 2.173159 2.238715 1.748129
#  [9] 2.462240 1.235369 1.303663 1.206459 1.104201 2.011822 1.002472

# %%
data.frame(vif_table)
# Out:
#                                 vif_table
# Size                            2.808452
# BHK                             3.129392
# Bathroom                        3.798571
# Area.Type.Super                 1.656889
# City.Bangalore                  2.159916
# City.Chennai                    2.173159
# City.Hyderabad                  2.238715
# City.Kolkata                    1.748129
# City.Mumbai                     2.462240
# Furnishing.Status.Furnished     1.235369
# Furnishing.Status.SemiFurnished 1.303663
# Tenant.Preferred.Bachelors      1.206459
# Tenant.Preferred.Family         1.104201
# Point.of.Contact.ContactAgent   2.011822
# Point.of.Contact.ContactBuilder 1.002472

# %% [markdown]
# ### Remove `Point.of.Contact.ContactBuilder`

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    Area.Type.Super +
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + Area.Type.Super +
#     City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata +
#     City.Mumbai + Furnishing.Status.Furnished + Furnishing.Status.SemiFurnished +
#     Tenant.Preferred.Bachelors + Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139425  -17988   -2143   11892  940847
#
# Coefficients:
#                                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)                     -26467.85    3403.01  -7.778 9.79e-15 ***
# Size                                36.60       1.92  19.062  < 2e-16 ***
# BHK                               4661.01    1548.75   3.010 0.002636 **
# Bathroom                          8407.04    1601.58   5.249 1.62e-07 ***
# Area.Type.Super                  -2727.27    1890.98  -1.442 0.149326
# City.Bangalore                  -10949.37    2773.82  -3.947 8.07e-05 ***
# ...

# %%
vif_table <- VIF(model)
data.frame(vif_table)
# Out:
#                                 vif_table
# Size                            2.808429
# BHK                             3.129161
# Bathroom                        3.798541
# Area.Type.Super                 1.656815
# City.Bangalore                  2.159914
# City.Chennai                    2.173155
# City.Hyderabad                  2.237117
# City.Kolkata                    1.748123
# City.Mumbai                     2.462237
# Furnishing.Status.Furnished     1.235205
# Furnishing.Status.SemiFurnished 1.303289
# Tenant.Preferred.Bachelors      1.206433
# Tenant.Preferred.Family         1.104182
# Point.of.Contact.ContactAgent   2.011731

# %%
data.frame(vif_table)$vif_table
# Out:
#  [1] 2.808429 3.129161 3.798541 1.656815 2.159914 2.173155 2.237117 1.748123
#  [9] 2.462237 1.235205 1.303289 1.206433 1.104182 2.011731

# %% [markdown]
# ### Remove Furnishing.Status.SemiFurnished

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    Area.Type.Super +
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + Area.Type.Super +
#     City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata +
#     City.Mumbai + Furnishing.Status.Furnished + Tenant.Preferred.Bachelors +
#     Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139529  -18115   -2346   11874  940777
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -27025.949   3335.972  -8.101 7.57e-16 ***
# Size                              36.510      1.917  19.047  < 2e-16 ***
# BHK                             4630.798   1548.249   2.991 0.002801 **
# Bathroom                        8360.037   1600.509   5.223 1.87e-07 ***
# Area.Type.Super                -2702.751   1890.662  -1.430 0.152947
# City.Bangalore                -11170.341   2760.928  -4.046 5.33e-05 ***
# City.Chennai                  -15306.996   2758.291  -5.549 3.09e-08 ***
# ...

# %%
vif_table <- VIF(model)
data.frame(vif_table)
# Out:
#                               vif_table
# Size                          2.798741
# BHK                           3.127438
# Bathroom                      3.793806
# Area.Type.Super               1.656412
# City.Bangalore                2.140078
# City.Chennai                  2.173153
# City.Hyderabad                2.235999
# City.Kolkata                  1.730371
# City.Mumbai                   2.456618
# Furnishing.Status.Furnished   1.031132
# Tenant.Preferred.Bachelors    1.193014
# Tenant.Preferred.Family       1.104091
# Point.of.Contact.ContactAgent 2.005669

# %%
data.frame(vif_table)$vif_table
# Out:
#  [1] 2.798741 3.127438 3.793806 1.656412 2.140078 2.173153 2.235999 1.730371
#  [9] 2.456618 1.031132 1.193014 1.104091 2.005669

# %% [markdown]
# ### Remove `Area.Type.Super`

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Bachelors + Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + City.Bangalore +
#     City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
#     Furnishing.Status.Furnished + Tenant.Preferred.Bachelors +
#     Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -140084  -18319   -2221   12017  941561
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -29278.348   2940.891  -9.956  < 2e-16 ***
# Size                              36.343      1.914  18.992  < 2e-16 ***
# BHK                             4777.407   1545.092   3.092 0.002005 **
# Bathroom                        8368.960   1600.749   5.228 1.82e-07 ***
# City.Bangalore                -11153.907   2761.339  -4.039 5.48e-05 ***
# City.Chennai                  -15319.638   2758.712  -5.553 3.03e-08 ***
# City.Hyderabad                -23789.309   2844.671  -8.363  < 2e-16 ***
# ...

# %%
vif_table <- VIF(model)
data.frame(vif_table)
# Out:
#                               vif_table
# Size                          2.788451
# BHK                           3.113715
# Bathroom                      3.793748
# City.Bangalore                2.140041
# City.Chennai                  2.173131
# City.Hyderabad                2.233987
# City.Kolkata                  1.722544
# City.Mumbai                   2.429561
# Furnishing.Status.Furnished   1.031114
# Tenant.Preferred.Bachelors    1.098116
# Tenant.Preferred.Family       1.089301
# Point.of.Contact.ContactAgent 1.697014

# %%
data.frame(vif_table)$vif_table
# Out:
#  [1] 2.788451 3.113715 3.793748 2.140041 2.173131 2.233987 1.722544 2.429561
#  [9] 1.031114 1.098116 1.089301 1.697014

# %% [markdown]
# ### Remove `Tenant.Preferred.Bachelors`

# %%
model <- lm(Rent ~ Size + BHK + Bathroom + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + BHK + Bathroom + City.Bangalore +
#     City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
#     Furnishing.Status.Furnished + Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -139743  -18278   -2257   12004  942444
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -29837.325   2909.797 -10.254  < 2e-16 ***
# Size                              36.278      1.913  18.962  < 2e-16 ***
# BHK                             4794.217   1545.202   3.103 0.001934 **
# Bathroom                        8394.792   1600.796   5.244 1.67e-07 ***
# City.Bangalore                -10934.073   2756.481  -3.967 7.44e-05 ***
# City.Chennai                  -15164.800   2756.448  -5.502 4.05e-08 ***
# City.Hyderabad                -23525.667   2837.779  -8.290  < 2e-16 ***
# ...

# %%
model <- lm(Rent ~ Size + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

summary(model)
# Out:
# Call:
# lm(formula = Rent ~ Size + City.Bangalore + City.Chennai + City.Hyderabad +
#     City.Kolkata + City.Mumbai + Furnishing.Status.Furnished +
#     Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -174093  -17402   -2134   11111  912438
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -14945.860   2327.136  -6.422 1.53e-10 ***
# Size                              49.309      1.256  39.246  < 2e-16 ***
# City.Bangalore                -14821.254   2746.009  -5.397 7.24e-08 ***
# City.Chennai                  -16781.075   2774.901  -6.047 1.64e-09 ***
# City.Hyderabad                -25509.580   2847.139  -8.960  < 2e-16 ***
# City.Kolkata                  -14877.794   3101.083  -4.798 1.68e-06 ***
# City.Mumbai                    45996.670   2790.580  16.483  < 2e-16 ***
# ...

# %%
vif_table <- VIF(model)
data.frame(vif_table)
# Out:
#                               vif_table
# Size                          2.786532
# BHK                           3.113498
# Bathroom                      3.793167
# City.Bangalore                2.132066
# City.Chennai                  2.169106
# City.Hyderabad                2.222705
# City.Kolkata                  1.722493
# City.Mumbai                   2.400026
# Furnishing.Status.Furnished   1.030540
# Tenant.Preferred.Family       1.058764
# Point.of.Contact.ContactAgent 1.618788

# %%
data.frame(vif_table)$vif_table
# Out:
#  [1] 2.786532 3.113498 3.793167 2.132066 2.169106 2.222705 1.722493 2.400026
#  [9] 1.030540 1.058764 1.618788

# %% [markdown]
# # Regression Diagnostics

# %%
# model <- lm(log(Rent) ~ Size + BHK + Bathroom + 
#                     City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
#                     Furnishing.Status.Furnished + 
#                     Tenant.Preferred.Family + 
#                     Point.of.Contact.ContactAgent)

# summary(model)

# %%
# Plot#1: 
plot(fitted(model), rstandard(model), pch=19, xlab='Fitted Values', ylab='Standardized Residuals')
# Out:
# plot without title

# %%
# Plot#2:
plot(Size, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(BHK, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(Bathroom, rstandard(model), pch=19, ylab='Standardized Residuals')

plot(City.Bangalore, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Chennai, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Hyderabad, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Kolkata, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Mumbai, rstandard(model), pch=19, ylab='Standardized Residuals')

plot(Furnishing.Status.Furnished, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(Tenant.Preferred.Family, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(Point.of.Contact.ContactAgent, rstandard(model), pch=19, ylab='Standardized Residuals')
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
?hist

# %%
# Plot#3:
hist(rstandard(model), xlab="Standardized Residuals", main="Histogram of Residuals", col='grey', breaks=30)
boxplot(rstandard(model), xlab="Standardized Residuals", main="Box Plot of Residuals", col='grey')
qqnorm(rstandard(model))
# Out:
# Plot with title "Histogram of Residuals"
# Plot with title "Box Plot of Residuals"
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# # Transformation

# %%
model <- lm(log(Rent) ~ Size + BHK + Bathroom + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

model_summary <- summary(model)
model_summary
# Out:
# Call:
# lm(formula = log(Rent) ~ Size + BHK + Bathroom + City.Bangalore +
#     City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
#     Furnishing.Status.Furnished + Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8220 -0.2432 -0.0148  0.2355  3.8088
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                    8.543e+00  2.793e-02 305.915  < 2e-16 ***
# Size                           4.027e-04  1.836e-05  21.933  < 2e-16 ***
# BHK                            2.444e-01  1.483e-02  16.480  < 2e-16 ***
# Bathroom                       1.494e-01  1.536e-02   9.725  < 2e-16 ***
# City.Bangalore                -1.487e-01  2.646e-02  -5.621 2.05e-08 ***
# City.Chennai                  -2.175e-01  2.645e-02  -8.222 2.84e-16 ***
# City.Hyderabad                -3.172e-01  2.724e-02 -11.647  < 2e-16 ***
# ...

# %%
# (model_summary$sigma)^2
# Out:
# [1] 0.1649212

# %%
rstandard(model)
# Out:
#            1            2            3            4            5            6
# -0.198935718  0.551355340  1.518148595  0.053788132  0.553758126 -0.326411229
#            7            8            9           10           11           12
#  0.102805988  0.667734303 -0.364373294  0.485621385 -0.652588222  0.093142064
#           13           14           15           16           17           18
#  0.294440647 -0.772271308  0.404199244 -0.203126005  0.112746040 -0.632028705
#           19           20           21           22           23           24
# -0.012350353 -0.798092452  0.689715466  0.218177579  1.142929075  0.706708824
#           25           26           27           28           29           30
# -1.544678503 -0.408516399  0.435312820  2.331359833  1.058382447  0.942609716
#           31           32           33           34           35           36
#  0.234662725  2.163293315 -1.074842079  1.063242847  0.136051567  0.360205233
# ...

# %%
y_pred = predict(model, newdata=train_set)
mean(( log(train_set$Rent) - y_pred)^2)
# Out:
# [1] 0.1643254

# %%
y_pred = predict(model, newdata=test_set)
mean(( log(test_set$Rent) - y_pred)^2)
# Out:
# [1] 0.1742664

# %%
# Plot#1: 
plot(fitted(model), rstandard(model), pch=19, xlab='Fitted Values', ylab='Standardized Residuals')
# Out:
# plot without title

# %%
outlier_idx1 <- which(std_residual == max(std_residual))
outlier_idx1
outlier_idx2 <- which(std_residual == min(std_residual))
outlier_idx2

X_new <- X[-c(outlier_idx1, outlier_idx2)]
Y_new <- Y[-c(outlier_idx1, outlier_idx2)]

# %%
# Plot#2:
plot(Size, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(BHK, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(Bathroom, rstandard(model), pch=19, ylab='Standardized Residuals')

plot(City.Bangalore, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Chennai, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Hyderabad, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Kolkata, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(City.Mumbai, rstandard(model), pch=19, ylab='Standardized Residuals')

plot(Furnishing.Status.Furnished, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(Tenant.Preferred.Family, rstandard(model), pch=19, ylab='Standardized Residuals')
plot(Point.of.Contact.ContactAgent, rstandard(model), pch=19, ylab='Standardized Residuals')
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
# Plot#3:
hist(rstandard(model), xlab="Standardized Residuals", main="Histogram of Residuals", col='grey', breaks=30)
boxplot(rstandard(model), xlab="Standardized Residuals", main="Box Plot of Residuals", col='grey')
qqnorm(rstandard(model))
# Out:
# Plot with title "Histogram of Residuals"
# Plot with title "Box Plot of Residuals"
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# # Outlier Removal

# %%
model <- lm(log(Rent) ~ Size + BHK + Bathroom + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent)

model_summary <- summary(model)
model_summary
# Out:
# Call:
# lm(formula = log(Rent) ~ Size + BHK + Bathroom + City.Bangalore +
#     City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
#     Furnishing.Status.Furnished + Tenant.Preferred.Family + Point.of.Contact.ContactAgent)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8220 -0.2432 -0.0148  0.2355  3.8088
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                    8.543e+00  2.793e-02 305.915  < 2e-16 ***
# Size                           4.027e-04  1.836e-05  21.933  < 2e-16 ***
# BHK                            2.444e-01  1.483e-02  16.480  < 2e-16 ***
# Bathroom                       1.494e-01  1.536e-02   9.725  < 2e-16 ***
# City.Bangalore                -1.487e-01  2.646e-02  -5.621 2.05e-08 ***
# City.Chennai                  -2.175e-01  2.645e-02  -8.222 2.84e-16 ***
# City.Hyderabad                -3.172e-01  2.724e-02 -11.647  < 2e-16 ***
# ...

# %%
# Plot#1: 
plot(fitted(model), rstandard(model), pch=19, xlab='Fitted Values', ylab='Standardized Residuals')
abline(h=c(3, -3), col="red", lwd=3)
# Out:
# plot without title

# %%
std_residual <- rstandard(model)

order(std_residual)
# Out:
#    [1] 1443 2850 2370 2485 1679 1083 2282 1432 1790  814 1685 2252 2945  159
#   [15] 1553 2747  795  998  200 1539   90 1975 2671 1198 1503 2071 2889 2218
#   [29] 1123 2290 1586  860 1412 2882  992 2061 2999 1874 2300 2084 1401  791
#   [43] 3248  322 2559  997  477  813 1334 1272 2112  441 2541 3092 2916 1811
#   [57] 2344  742  345 2186 2713 2183   54 1239 2309 2406 3230 1636  721  344
#   [71] 2807  894  789 1335 2274 1704 2765 3298 2293 2299  262 3215 2308 3262
#   [85] 1394 1753 2023 1455 1346 1296 2426  250  728 3119 2835 1745 1822 1671
#   [99] 2329 2010 2088 2650  252 2372 1594 1699 1889 2906 1013  699 1454 1787
#  [113] 2385 2564 1465 2722 1955  809 2325 1040 3131   38 2275 1915 2052  797
#  [127] 3172 2241 1167  320  777 3129  216  246 2819 2296 2769 2921 1458 2755
#  [141] 2886  629 3310 2770  743 3279  380  879  690 3158 2515 3116  993 2752
#  [155]   25  782  195  579 1653 2784  720  945 2640 2259 2105  305 1460 1114
# ...

# %%
std_residual <- rstandard(model)

# %%
is_outlier <- abs(std_residual) > 3

# %%
train_set[which(!is_outlier), ]
# Out:
#      Rent   Size BHK Bathroom Area.Type.Built Area.Type.Super City.Bangalore
# 1491  45000  670 2   2        0               0               0
# 4572  16000 1100 2   2        0               1               0
# 2754  30000  900 2   2        0               1               0
# 2678  25000  900 2   2        0               0               0
# 3064  16000  850 2   2        0               1               0
# 1496 250000 2729 4   5        0               0               0
# 3976 100000 3300 4   4        0               0               0
# 571   65000  710 2   2        0               0               0
# 4364  10000 1030 2   2        0               1               0
# 947   40000  710 2   2        0               0               0
# 2964  16500  950 2   1        0               0               0
# 2034   8000  400 1   1        0               1               1
# 4303  70000 3200 3   3        0               0               0
# ...

# %%
top_3 <- order(std_residual, decreasing=TRUE)[0:3]
top_3

# %%
model <- lm(log(Rent) ~ Size + BHK + Bathroom + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent, data=train_set[-top_3,])

model_summary <- summary(model)
model_summary

# %%
model <- lm(log(Rent) ~ Size + BHK + Bathroom + 
                    City.Bangalore + City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
                    Furnishing.Status.Furnished + 
                    Tenant.Preferred.Family + 
                    Point.of.Contact.ContactAgent, data=train_set[which(!is_outlier), ])

model_summary <- summary(model)
model_summary
# Out:
# Call:
# lm(formula = log(Rent) ~ Size + BHK + Bathroom + City.Bangalore +
#     City.Chennai + City.Hyderabad + City.Kolkata + City.Mumbai +
#     Furnishing.Status.Furnished + Tenant.Preferred.Family + Point.of.Contact.ContactAgent,
#     data = train_set[which(!is_outlier), ])
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.1944 -0.2366 -0.0143  0.2343  1.2214
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                    8.526e+00  2.545e-02 335.052  < 2e-16 ***
# Size                           4.155e-04  1.709e-05  24.313  < 2e-16 ***
# BHK                            2.497e-01  1.349e-02  18.513  < 2e-16 ***
# Bathroom                       1.398e-01  1.406e-02   9.943  < 2e-16 ***
# City.Bangalore                -1.422e-01  2.407e-02  -5.907 3.85e-09 ***
# City.Chennai                  -2.120e-01  2.408e-02  -8.806  < 2e-16 ***
# City.Hyderabad                -3.084e-01  2.481e-02 -12.430  < 2e-16 ***
# ...

# %%
# Plot#1: 
plot(fitted(model), rstandard(model), pch=19, xlab='Fitted Values', ylab='Standardized Residuals')
# Out:
# plot without title

# %%
y_pred = predict(model, newdata=train_set)
mean(( log(train_set$Rent) - y_pred)^2)

y_pred = predict(model, newdata=test_set)
mean(( log(test_set$Rent) - y_pred)^2)
# Out:
# [1] 0.1644816
# [1] 0.1739342
